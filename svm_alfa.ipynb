# %%
import pandas as pd

archivos_lunes = [
    'series_originales/bitrate_original_lun_0.csv',
    'series_originales/bitrate_original_lun_1.csv',
    'series_ataque65/bitrate_attack_lun2.csv',
    'series_originales/bitrate_original_lun_3.csv',
    'series_originales/bitrate_original_lun_4.csv',
    'series_ataque65/bitrate_attack_lun5.csv',
    'series_originales/bitrate_original_lun_6.csv',
    'series_originales/bitrate_original_lun_7.csv'
]

archivos_martes = [
    'series_originales/bitrate_original_mar_0.csv',
    'series_originales/bitrate_original_mar_1.csv',
    'series_ataque65/bitrate_attack_mar2.csv',
    'series_originales/bitrate_original_mar_3.csv',
    'series_originales/bitrate_original_mar_4.csv',
    'series_ataque65/bitrate_attack_mar5.csv',
    'series_originales/bitrate_original_mar_6.csv',
    'series_originales/bitrate_original_mar_7.csv'
]


archivos_miercoles = [
    'series_originales/bitrate_original_mie_0.csv',
    'series_originales/bitrate_original_mie_1.csv',
    'series_ataque65/bitrate_attack_mie2.csv',
    'series_originales/bitrate_original_mie_3.csv',
    'series_originales/bitrate_original_mie_4.csv',
    'series_ataque65/bitrate_attack_mie5.csv',
    'series_originales/bitrate_original_mie_6.csv',
    'series_originales/bitrate_original_mie_7.csv'
]


archivos_jueves = [
    'series_originales/bitrate_original_jue_0.csv',
    'series_originales/bitrate_original_jue_1.csv',
    'series_ataque65/bitrate_attack_jue2.csv',
    'series_originales/bitrate_original_jue_3.csv',
    'series_originales/bitrate_original_jue_4.csv',
    'series_ataque65/bitrate_attack_jue5.csv',
    'series_originales/bitrate_original_jue_6.csv',
    'series_originales/bitrate_original_jue_7.csv'
]


archivos_viernes = [
    'series_originales/bitrate_original_vie_0.csv',
    'series_originales/bitrate_original_vie_1.csv',
    'series_ataque65/bitrate_attack_vie2.csv',
    'series_originales/bitrate_original_vie_3.csv',
    'series_originales/bitrate_original_vie_4.csv',
    'series_ataque65/bitrate_attack_vie5.csv',
    'series_originales/bitrate_original_vie_6.csv',
    'series_originales/bitrate_original_vie_7.csv'
]

print(archivos_miercoles)

df_concatenado_lunes = pd.concat([pd.read_csv(archivo1, header=None) for archivo1 in archivos_lunes], axis=0, ignore_index=True)
df_concatenado_martes = pd.concat([pd.read_csv(archivo2, header=None) for archivo2 in archivos_martes], axis=0, ignore_index=True)
df_concatenado_miercoles = pd.concat([pd.read_csv(archivo3, header=None) for archivo3 in archivos_miercoles], axis=0, ignore_index=True)
df_concatenado_jueves = pd.concat([pd.read_csv(archivo4, header=None) for archivo4 in archivos_jueves], axis=0, ignore_index=True)
df_concatenado_viernes = pd.concat([pd.read_csv(archivo5, header=None) for archivo5 in archivos_viernes], axis=0, ignore_index=True)


#df_concatenado_lunes.to_csv('series_concatenadas/archivo_concatenado_lunes.csv', index=False, header=False)
#df_concatenado_martes.to_csv('series_concatenadas/archivo_concatenado_martes.csv', index=False, header=False)
#df_concatenado_miercoles.to_csv('series_concatenadas/archivo_concatenado_miercoles.csv', index=False, header=False)
#df_concatenado_jueves.to_csv('series_concatenadas/archivo_concatenado_jueves.csv', index=False, header=False)
#df_concatenado_viernes.to_csv('series_concatenadas/archivo_concatenado_viernes.csv', index=False, header=False)

#df_concatenado_lunes.to_csv('series_concatenadas/archivo_concatenado_lunes_cambio.csv', index=False, header=False)
#df_concatenado_martes.to_csv('series_concatenadas/archivo_concatenado_martes_cambio.csv', index=False, header=False)
##df_concatenado_miercoles.to_csv('series_concatenadas/archivo_concatenado_miercoles_cambio_0_5.csv', index=False, header=False)
#df_concatenado_jueves.to_csv('series_concatenadas/archivo_concatenado_jueves_cambio.csv', index=False, header=False)
#df_concatenado_viernes.to_csv('series_concatenadas/archivo_concatenado_viernes_cambio.csv', index=False, header=False)
# Out:
# ['series_originales/bitrate_original_mie_0.csv', 'series_originales/bitrate_original_mie_1.csv', 'series_ataque65/bitrate_attack_mie2.csv', 'series_originales/bitrate_original_mie_3.csv', 'series_originales/bitrate_original_mie_4.csv', 'series_ataque65/bitrate_attack_mie5.csv', 'series_originales/bitrate_original_mie_6.csv', 'series_originales/bitrate_original_mie_7.csv']

# %%
import pandas as pd
import matplotlib.pyplot as plt


data1 = pd.read_csv("series_ataque65/bitrate_attack_mie1.csv", header=None)[0] 
data2 = pd.read_csv("series_originales/bitrate_original_mie_1.csv", header=None)[0] 


data1 = pd.read_csv("series_sumadas/serie_sumada_mie_2.csv", header=None)[0] 
data2 = pd.read_csv("series_originales/bitrate_original_mie_1.csv", header=None)[0] 



plt.figure(figsize=(10,5))
plt.plot(data1, label="Ataque generado")
plt.plot(data2, label="Original")
plt.legend()
plt.xlabel("Ventana 15 minutos")
plt.ylabel("Bitrate (bps)")
plt.title("Ventana ejemplo de 15 minutos generadas con parámetros alpha estables")
#plt.savefig("figuras_memoria/serie_sintetica.pdf")
#plt.savefig("figuras_memoria/serie_sintetica.svg")
plt.show()


plt.figure(figsize=(10,5))
plt.plot(data1, label="65%")
plt.plot(data2, label="Original")
plt.legend()
plt.xlabel("Ventana 15 minutos")
plt.ylabel("Bitrate (bps)")
plt.title("Ventana ejemplo de 15 minutos con reducción del ataque al 65%")
#plt.savefig("figuras_memoria/ventana_ataque_con_reduccion.pdf")
#plt.savefig("figuras_memoria/ventana_ataque_con_reduccion.svg")
plt.show()

# %%
import matplotlib.pyplot as plt

df_concatenado_lunes = pd.read_csv("series_concatenadas/archivo_concatenado_lunes.csv", header=None)[0]
df_concatenado_lunes_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_lunes_sin_ataque.csv", header=None)[0]
df_concatenado_martes = pd.read_csv("series_concatenadas/archivo_concatenado_martes.csv", header=None)[0]
df_concatenado_martes_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_martes_sin_ataque.csv", header=None)[0]
df_concatenado_miercoles = pd.read_csv("series_concatenadas/archivo_concatenado_miercoles.csv", header=None)[0]
df_concatenado_miercoles_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque.csv", header=None)[0]
df_concatenado_jueves = pd.read_csv("series_concatenadas/archivo_concatenado_jueves.csv", header=None)[0]
df_concatenado_jueves_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_jueves_sin_ataque.csv", header=None)[0]
df_concatenado_viernes = pd.read_csv("series_concatenadas/archivo_concatenado_viernes.csv", header=None)[0]
df_concatenado_viernes_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_viernes_sin_ataque.csv", header=None)[0]




fig, axes = plt.subplots(5, 1, figsize=(10, 12), sharex=True)

for ax in axes:
    ax.axvline(x=1801, color='green', linestyle='--', label='Empieza a haber ataque')
    ax.axvline(x=2700, color='red', linestyle='--', label='Deja de haber ataque')
    ax.axvline(x=4501, color='green', linestyle='--', label='Empieza a haber ataque')
    ax.axvline(x=5400, color='red', linestyle='--', label='Deja de haber ataque')

# Lunes: graficar serie con ataque y sin ataque
axes[0].plot(df_concatenado_lunes, label='Lunes (con ataque)')
axes[0].plot(df_concatenado_lunes_sin_ataque, label='Lunes (sin ataque)')
axes[0].legend()

# Martes
axes[1].plot(df_concatenado_martes, label='Martes (con ataque)')
axes[1].plot(df_concatenado_martes_sin_ataque, label='Martes (sin ataque)')
axes[1].legend()

# Miércoles
axes[2].plot(df_concatenado_miercoles, label='Miércoles (con ataque)')
axes[2].plot(df_concatenado_miercoles_sin_ataque, label='Miércoles (sin ataque)')
axes[2].legend()

# Jueves
axes[3].plot(df_concatenado_jueves, label='Jueves (con ataque)')
axes[3].plot(df_concatenado_jueves_sin_ataque, label='Jueves (sin ataque)')
axes[3].legend()

# Viernes
axes[4].plot(df_concatenado_viernes, label='Viernes (con ataque)')
axes[4].plot(df_concatenado_viernes_sin_ataque, label='Viernes (sin ataque)')
axes[4].legend()

plt.xlabel('Índice de la muestra')
plt.ylabel('Bitrate')
plt.suptitle('Series concatenadas diarias (no difs finitas)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df_concatenado_miercoles, label="Ataque alfa estables")
plt.plot(df_concatenado_miercoles_sin_ataque, label="Original")
plt.axvline(x=1801, color='green', linestyle='--', label='Empieza a haber ataque')
plt.axvline(x=2700, color='red', linestyle='--', label='Deja de haber ataque')
plt.axvline(x=4501, color='green', linestyle='--', label='Empieza a haber ataque')
plt.axvline(x=5400, color='red', linestyle='--', label='Deja de haber ataque')
plt.legend()
plt.xlabel("Muestras")
plt.ylabel("Bitrate (bps)")
plt.title("Serie concatenada con ataque generado por alfa estables")
#plt.savefig("figuras_memoria/serie_concatenada_alfa_miercoles.pdf")
#plt.savefig("figuras_memoria/serie_concatenada_alfa_miercoles.svg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


data1 = pd.read_csv("series_concatenadas/archivo_concatenado_miercoles_diff.csv", header=None)[0] 
data2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)[0] 



plt.figure(figsize=(10,5))
plt.plot(data1, label="Ataque alfa estables")
plt.plot(data2, label="Original")
plt.legend()
plt.xlabel("Muestras")
plt.ylabel("Bitrate (bps)")
plt.title("Diferencias finitas aplicadas a la serie con ataque generado con alfa estables")
#plt.savefig("figuras_memoria/difs_finitas_alfa.pdf")
#plt.savefig("figuras_memoria/difs_finitas_alfa.svg")
plt.show()

# %%
from utilities import *
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit
import matplotlib.pyplot as plt

# Abrir archivos originales (se usan para calcular x1 y x2)
df1 = pd.read_csv("series_concatenadas/archivo_concatenado_miercoles_diff.csv", header=None)
df2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)

# Ruta del archivo generado por MATLAB
file_path = "matlab_norm/alpha_fit_normalized_miercoles_concatenado_desl_p1.csv"
df = pd.read_csv(file_path, sep=",")
print("Columnas del DataFrame:", df.columns.tolist())

# Calcular x1 y x2 usando ventanas 
x1 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df1[898*j+720:898*(j+1)] - df1[898*j:898*j+720].mean()) / df1[898*j:898*j+720].std()
        for j in range(len(df1) // 898)
    ]
])
x2 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df2[898*j+720:898*(j+1)] - df2[898*j:898*j+720].mean()) / df2[898*j:898*j+720].std()
        for j in range(len(df2) // 898)
    ]
])

xMeanStd = pd.concat([x1, x2], axis=0)


n_blocks = len(xMeanStd)    
n_rows = len(df)            
k = n_rows // n_blocks      
remainder = n_rows % n_blocks  

mean_values = []
std_values = []
for i, (mean_val, std_val) in enumerate(xMeanStd):
    reps = k + (1 if i < remainder else 0)
    mean_values.extend([mean_val] * reps)
    std_values.extend([std_val] * reps)

df["mean_values"] = mean_values
df["std_values"] = std_values

# Seleccionar las variables relevantes para el modelo 
#selected_features = ["beta_values", "gamma_values", "std_values"]
selected_features = ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values"]
Y = df["attack_value"].astype(float)  # Variable dependiente
X = df[selected_features].astype(float)  # Variables predictoras

X = sm.add_constant(X)

# Entrenar modelo de regresión logística
model = Logit(Y, X)
results = model.fit()
print(results.summary())

# REPRESENTACIÓN CON SVM
from sklearn import svm
clf = svm.SVC(class_weight="balanced")
clf.fit(X, Y)

# Predicciones y matriz de confusión
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
predictions = clf.predict(X)
cm = confusion_matrix(Y, predictions, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Attack", "Attack"])
disp.plot(cmap=plt.cm.Blues)
plt.title("       Matriz de confusion usando SVM para ataque generado por alfa estables")
#plt.savefig("figuras_memoria/conf_mtx_miercoles_alfa.svg")
#plt.savefig("figuras_memoria/conf_mtx_miercoles_alfa.pdf")
plt.show()

# Métricas
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y, predictions)
precision = precision_score(Y, predictions)
recall = recall_score(Y, predictions)
f1 = f1_score(Y, predictions)
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 score: ", f1)

# Curva ROC
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(Y, predictions)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic, all parameters')
plt.legend(loc="lower right")
plt.show()
# Out:
# Columnas del DataFrame: ['alpha_values', 'beta_values', 'gamma_values', 'delta_values', 'attack_value']
# Optimization terminated successfully.
#          Current function value: 0.639282
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           attack_value   No. Observations:                12604
# Model:                          Logit   Df Residuals:                    12597
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 11 Apr 2025   Pseudo R-squ.:                 0.07771
# Time:                        11:28:02   Log-Likelihood:                -8057.5
# converged:                       True   LL-Null:                       -8736.4
# Covariance Type:            nonrobust   LLR p-value:                3.277e-290
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -1.3506      0.193     -6.981      0.000      -1.730      -0.971
# alpha_values    -0.3904      0.103     -3.805      0.000      -0.591      -0.189
# beta_values      0.2467      0.053      4.632      0.000       0.142       0.351
# gamma_values     0.3387      0.103      3.298      0.001       0.137       0.540
# delta_values    -1.0502      0.172     -6.109      0.000      -1.387      -0.713
# mean_values     13.1056      1.039     12.611      0.000      11.069      15.142
# std_values       1.9964      0.085     23.463      0.000       1.830       2.163
# ================================================================================
# Accuracy:  0.6182164392256426
# Precision:  0.7638101983002833
# Recall:  0.34227229450967944
# F1 score:  0.472715318869165

# %%
from utilities import *
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

# Abrir archivos originales (se usan para calcular x1 y x2)
df1 = pd.read_csv("series_concatenadas/archivo_concatenado_miercoles_diff.csv", header=None)
df2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)

# Ruta del archivo generado por MATLAB
file_path = "matlab_norm/alpha_fit_normalized_miercoles_concatenado_desl_p1.csv"
df = pd.read_csv(file_path, sep=",")
print("Columnas del DataFrame:", df.columns.tolist())

# Calcular x1 y x2 usando ventanas 
x1 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df1[898*j+720:898*(j+1)] - df1[898*j:898*j+720].mean()) / df1[898*j:898*j+720].std()
        for j in range(len(df1) // 898)
    ]
])
x2 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df2[898*j+720:898*(j+1)] - df2[898*j:898*j+720].mean()) / df2[898*j:898*j+720].std()
        for j in range(len(df2) // 898)
    ]
])

xMeanStd = pd.concat([x1, x2], axis=0)


n_blocks = len(xMeanStd)    
n_rows = len(df)            
k = n_rows // n_blocks      
remainder = n_rows % n_blocks  

mean_values = []
std_values = []
for i, (mean_val, std_val) in enumerate(xMeanStd):
    reps = k + (1 if i < remainder else 0)
    mean_values.extend([mean_val] * reps)
    std_values.extend([std_val] * reps)

df["mean_values"] = mean_values
df["std_values"] = std_values



# Seleccionar las variables relevantes para el modelo
selected_features = ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values"]
Y = df["attack_value"].astype(float)  # Variable dependiente (0 o 1)
X = df[selected_features].astype(float)

X = sm.add_constant(X)  

# Entrenar el modelo Logit
model = Logit(Y, X)
results = model.fit()
print(results.summary())

pred_probs = results.predict(X)              
pred_classes = (pred_probs >= 0.5).astype(int)  

# Matriz de confusión y métricas


cm = confusion_matrix(Y, pred_classes, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Attack", "Attack"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

accuracy = accuracy_score(Y, pred_classes)
precision = precision_score(Y, pred_classes)
recall = recall_score(Y, pred_classes)
f1 = f1_score(Y, pred_classes)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)

# Curva ROC
fpr, tpr, _ = roc_curve(Y, pred_classes)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - Logistic Regression')
plt.legend(loc="lower right")
plt.show()
# Out:
# Columnas del DataFrame: ['alpha_values', 'beta_values', 'gamma_values', 'delta_values', 'attack_value']
# Optimization terminated successfully.
#          Current function value: 0.639282
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           attack_value   No. Observations:                12604
# Model:                          Logit   Df Residuals:                    12597
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 11 Apr 2025   Pseudo R-squ.:                 0.07771
# Time:                        11:28:19   Log-Likelihood:                -8057.5
# converged:                       True   LL-Null:                       -8736.4
# Covariance Type:            nonrobust   LLR p-value:                3.277e-290
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -1.3506      0.193     -6.981      0.000      -1.730      -0.971
# alpha_values    -0.3904      0.103     -3.805      0.000      -0.591      -0.189
# beta_values      0.2467      0.053      4.632      0.000       0.142       0.351
# gamma_values     0.3387      0.103      3.298      0.001       0.137       0.540
# delta_values    -1.0502      0.172     -6.109      0.000      -1.387      -0.713
# mean_values     13.1056      1.039     12.611      0.000      11.069      15.142
# std_values       1.9964      0.085     23.463      0.000       1.830       2.163
# ================================================================================
# Accuracy: 0.626864487464297
# Precision: 0.662269129287599
# Recall: 0.5177721358298952
# F1 score: 0.5811737465491139

# %%
from utilities import *
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

# Abrir archivos originales (se usan para calcular x1 y x2)
df1 = pd.read_csv("series_concatenadas/archivo_concatenado_miercoles_diff.csv", header=None)
#df1 = pd.read_csv("series_concatenadas/archivo_concatenado_miercoles_cambio_0_55_diff.csv", header=None)
df2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)

# Ruta del archivo generado por MATLAB
file_path = "matlab_norm/alpha_fit_normalized_miercoles_concatenado_desl_p1.csv"
#file_path = "matlab_norm/cambio_intensidades/alpha_fit_normalized_miercoles_concatenado_alfa_desl_p1_intens_cambio_0_55.csv"
df = pd.read_csv(file_path, sep=",")
print("Columnas del DataFrame:", df.columns.tolist())

# Calcular x1 y x2 usando ventanas 
x1 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df1[898*j+720:898*(j+1)] - df1[898*j:898*j+720].mean()) / df1[898*j:898*j+720].std()
        for j in range(len(df1) // 898)
    ]
])
x2 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df2[898*j+720:898*(j+1)] - df2[898*j:898*j+720].mean()) / df2[898*j:898*j+720].std()
        for j in range(len(df2) // 898)
    ]
])
xMeanStd = pd.concat([x1, x2], axis=0)


n_blocks = len(xMeanStd)    
n_rows = len(df)            
k = n_rows // n_blocks      
remainder = n_rows % n_blocks  

mean_values = []
std_values = []
for i, (mean_val, std_val) in enumerate(xMeanStd):
    reps = k + (1 if i < remainder else 0)
    mean_values.extend([mean_val] * reps)
    std_values.extend([std_val] * reps)

df["mean_values"] = mean_values
df["std_values"] = std_values




# Seleccionar las variables relevantes para el modelo
selected_features = ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values"]
Y = df["attack_value"].astype(float)  # Variable dependiente (0 o 1)
X = df[selected_features].astype(float)

# Entrenar el modelo SVM
clf = svm.SVC(class_weight="balanced")  # "balanced" para dar más peso a la clase minoritaria si la hay
clf.fit(X, Y)

predictions = clf.predict(X)

# Matriz de confusión y métricas
cm = confusion_matrix(Y, predictions, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Attack", "Attack"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - SVM")
plt.show()

accuracy = accuracy_score(Y, predictions)
precision = precision_score(Y, predictions)
recall = recall_score(Y, predictions)
f1 = f1_score(Y, predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)

# Curva ROC
scores = clf.decision_function(X)

fpr, tpr, _ = roc_curve(Y, scores)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - SVM')
plt.legend(loc="lower right")
plt.show()
# Out:
# Columnas del DataFrame: ['alpha_values', 'beta_values', 'gamma_values', 'delta_values', 'attack_value']
# Accuracy: 0.6188511583624247
# Precision: 0.7635467980295566
# Recall: 0.34433513170422086
# F1 score: 0.4746281714785652

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=fpr, y=tpr, mode='lines', name=f'ROC Curve (AUC = {roc_auc:.2f})'))
fig.add_trace(go.Scatter(x=[0, 1], y=[0, 1], mode='lines', name='Random Guess', line=dict(dash='dash')))

fig.update_layout(
    title='ROC Curve',
    xaxis_title='False Positive Rate',
    yaxis_title='True Positive Rate',
    width=700,
    height=500
)
#plt.savefig("figuras_memoria/roc_curve_din_alfa.pdf")
#plt.savefig("figuras_memoria/roc_curve_din_alfa.svg")
fig.show()

# %%
#CAMBIO INTENSIDADES
import pandas as pd

archivos_miercoles = [
    'series_originales/bitrate_original_mie_0.csv',
    'series_originales/bitrate_original_mie_1.csv',
    'series_alfa_cambio/serie_cambio_mie2_1_4.csv',
    'series_originales/bitrate_original_mie_3.csv',
    'series_originales/bitrate_original_mie_4.csv',
    'series_alfa_cambio/serie_cambio_mie5_1_4.csv',
    'series_originales/bitrate_original_mie_6.csv',
    'series_originales/bitrate_original_mie_7.csv'
]

df_concatenado_miercoles = pd.concat([pd.read_csv(archivo3, header=None) for archivo3 in archivos_miercoles], axis=0, ignore_index=True)

#df_concatenado_miercoles.to_csv('series_concatenadas/archivo_concatenado_miercoles_cambio_1_4.csv', index=False, header=False)

# %%
archivo_concatenado_miercoles_com = pd.read_csv("series_concatenadas/archivo_concatenado_miercoles_cambio_0_55.csv", header=None)
archivo_concatenado_miercoles_com_diff = archivo_concatenado_miercoles_com.diff()
#archivo_concatenado_miercoles_com_diff.dropna().to_csv('series_concatenadas/archivo_concatenado_miercoles_cambio_0_55_diff.csv', index=False, header=False)
