# %%
import pandas as pd

archivos_lunes = [
    'series_originales/bitrate_original_lun_0.csv',
    'series_originales/bitrate_original_lun_1.csv',
    'ataque_rampa/bitrate_interval_lun2.csv',
    'series_originales/bitrate_original_lun_3.csv',
    'series_originales/bitrate_original_lun_4.csv',
    'ataque_rampa/bitrate_interval_lun5.csv',
    'series_originales/bitrate_original_lun_6.csv',
    'series_originales/bitrate_original_lun_7.csv'
]

archivos_martes = [
    'series_originales/bitrate_original_mar_0.csv',
    'series_originales/bitrate_original_mar_1.csv',
    'ataque_rampa/bitrate_interval_mar2.csv',
    'series_originales/bitrate_original_mar_3.csv',
    'series_originales/bitrate_original_mar_4.csv',
    'ataque_rampa/bitrate_interval_mar5.csv',
    'series_originales/bitrate_original_mar_6.csv',
    'series_originales/bitrate_original_mar_7.csv'
]

archivos_miercoles = [
    'series_originales/bitrate_original_mie_0.csv',
    'series_originales/bitrate_original_mie_1.csv',
    'ataque_rampa/bitrate_interval_mie2.csv',
    'series_originales/bitrate_original_mie_3.csv',
    'series_originales/bitrate_original_mie_4.csv',
    'ataque_rampa/bitrate_interval_mie5.csv',
    'series_originales/bitrate_original_mie_6.csv',
    'series_originales/bitrate_original_mie_7.csv'
]

archivos_jueves = [
    'series_originales/bitrate_original_jue_0.csv',
    'series_originales/bitrate_original_jue_1.csv',
    'ataque_rampa/bitrate_interval_jue2.csv',
    'series_originales/bitrate_original_jue_3.csv',
    'series_originales/bitrate_original_jue_4.csv',
    'ataque_rampa/bitrate_interval_jue5.csv',
    'series_originales/bitrate_original_jue_6.csv',
    'series_originales/bitrate_original_jue_7.csv'
]


archivos_viernes = [
    'series_originales/bitrate_original_vie_0.csv',
    'series_originales/bitrate_original_vie_1.csv',
    'ataque_rampa/bitrate_interval_vie2.csv',
    'series_originales/bitrate_original_vie_3.csv',
    'series_originales/bitrate_original_vie_4.csv',
    'ataque_rampa/bitrate_interval_vie5.csv',
    'series_originales/bitrate_original_vie_6.csv',
    'series_originales/bitrate_original_vie_7.csv'
]

df_concatenado_lunes = pd.concat([pd.read_csv(archivo1, header=None) for archivo1 in archivos_lunes], axis=0, ignore_index=True)
df_concatenado_martes = pd.concat([pd.read_csv(archivo2, header=None) for archivo2 in archivos_martes], axis=0, ignore_index=True)
df_concatenado_miercoles = pd.concat([pd.read_csv(archivo3, header=None) for archivo3 in archivos_miercoles], axis=0, ignore_index=True)
df_concatenado_jueves = pd.concat([pd.read_csv(archivo4, header=None) for archivo4 in archivos_jueves], axis=0, ignore_index=True)
df_concatenado_viernes = pd.concat([pd.read_csv(archivo5, header=None) for archivo5 in archivos_viernes], axis=0, ignore_index=True)


#df_concatenado_lunes.to_csv('series_concatenadas_rampa/archivo_concatenado_lunes.csv', index=False, header=False)
#df_concatenado_martes.to_csv('series_concatenadas_rampa/archivo_concatenado_martes.csv', index=False, header=False)
#df_concatenado_miercoles.to_csv('series_concatenadas_rampa/archivo_concatenado_miercoles.csv', index=False, header=False)
#df_concatenado_jueves.to_csv('series_concatenadas_rampa/archivo_concatenado_jueves.csv', index=False, header=False)
#df_concatenado_viernes.to_csv('series_concatenadas_rampa/archivo_concatenado_viernes.csv', index=False, header=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt


data1 = pd.read_csv("ataque_rampa/bitrate_interval_mie1.csv", header=None)[0] 
data2 = pd.read_csv("series_originales/bitrate_original_mie_1.csv", header=None)[0] 



plt.figure(figsize=(10,5))
plt.plot(data1, label="Rampa")
plt.plot(data2, label="Original")
plt.legend()
plt.xlabel("Ventana 15 minutos")
plt.ylabel("Bitrate (bps)")
plt.title("Ventana ejemplo de 15 minutos con ataque de rampa")
#plt.savefig("figuras_memoria/ventana_ataque_rampa.pdf")
#plt.savefig("figuras_memoria/ventana_ataque_rampa.svg")
plt.show()

# %%
import matplotlib.pyplot as plt

df_concatenado_lunes = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_lunes.csv", header=None)[0]
df_concatenado_lunes_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_lunes_sin_ataque.csv", header=None)[0]
df_concatenado_martes = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_martes.csv", header=None)[0]
df_concatenado_martes_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_martes_sin_ataque.csv", header=None)[0]
df_concatenado_miercoles = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_miercoles.csv", header=None)[0]
df_concatenado_miercoles_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque.csv", header=None)[0]
df_concatenado_jueves = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_jueves.csv", header=None)[0]
df_concatenado_jueves_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_jueves_sin_ataque.csv", header=None)[0]
df_concatenado_viernes = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_viernes.csv", header=None)[0]
df_concatenado_viernes_sin_ataque = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_viernes_sin_ataque.csv", header=None)[0]


fig, axes = plt.subplots(5, 1, figsize=(10, 12), sharex=True)

for ax in axes:
    ax.axvline(x=1801, color='green', linestyle='--', label='Empieza a haber ataque')
    ax.axvline(x=2700, color='red', linestyle='--', label='Deja de haber ataque')
    ax.axvline(x=4501, color='green', linestyle='--', label='Empieza a haber ataque')
    ax.axvline(x=5400, color='red', linestyle='--', label='Deja de haber ataque')

# Lunes: graficar serie con ataque y sin ataque
axes[0].plot(df_concatenado_lunes, label='Lunes (con ataque)')
axes[0].plot(df_concatenado_lunes_sin_ataque, label='Lunes (sin ataque)')
axes[0].legend()

# Martes
axes[1].plot(df_concatenado_martes, label='Martes (con ataque)')
axes[1].plot(df_concatenado_martes_sin_ataque, label='Martes (sin ataque)')
axes[1].legend()

# Miércoles
axes[2].plot(df_concatenado_miercoles, label='Miércoles (con ataque)')
axes[2].plot(df_concatenado_miercoles_sin_ataque, label='Miércoles (sin ataque)')
axes[2].legend()

# Jueves
axes[3].plot(df_concatenado_jueves, label='Jueves (con ataque)')
axes[3].plot(df_concatenado_jueves_sin_ataque, label='Jueves (sin ataque)')
axes[3].legend()

# Viernes
axes[4].plot(df_concatenado_viernes, label='Viernes (con ataque)')
axes[4].plot(df_concatenado_viernes_sin_ataque, label='Viernes (sin ataque)')
axes[4].legend()

plt.xlabel('Índice de la muestra')
plt.ylabel('Bitrate')
plt.suptitle('Series concatenadas diarias (no difs finitas)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df_concatenado_miercoles, label="Rampa")
plt.plot(df_concatenado_miercoles_sin_ataque, label="Original")
plt.axvline(x=1801, color='green', linestyle='--', label='Empieza a haber ataque')
plt.axvline(x=2700, color='red', linestyle='--', label='Deja de haber ataque')
plt.axvline(x=4501, color='green', linestyle='--', label='Empieza a haber ataque')
plt.axvline(x=5400, color='red', linestyle='--', label='Deja de haber ataque')
plt.legend()
plt.xlabel("Muestras")
plt.ylabel("Bitrate (bps)")
plt.title("Serie concatenada con ataque de rampa")
#plt.savefig("figuras_memoria/serie_concatenada_rampa_miercoles.pdf")
#plt.savefig("figuras_memoria/serie_concatenada_rampa_miercoles.svg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Supongamos que data2 es una Series:
data1 = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_miercoles_diff.csv", header=None)[0] #ELEGIR ENTRE LA 1 Y LA 2
data2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)[0] #ELEGIR ENTRE LA 1 Y LA 2



plt.figure(figsize=(10,5))
plt.plot(data1, label="Rampa")
plt.plot(data2, label="Original")
plt.legend()
plt.xlabel("Muestras")
plt.ylabel("Bitrate (bps)")
plt.title("Diferencias finitas aplicadas a la serie con ataque en rampa")
#plt.savefig("figuras_memoria/difs_finitas_rampa.pdf")
#plt.savefig("figuras_memoria/difs_finitas_rampa.svg")
plt.show()

# %%
from utilities import *
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit
import matplotlib.pyplot as plt

# Abrir archivos originales (se usan para calcular x1 y x2)
df1 = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_miercoles_diff.csv", header=None)
df2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)

# Ruta del archivo generado por MATLAB
file_path = "matlab_norm/alpha_fit_normalized_miercoles_concatenado_rampa_desl_p1.csv"
df = pd.read_csv(file_path, sep=",")
print("Columnas del DataFrame:", df.columns.tolist())

# Calcular x1 y x2 usando ventanas (se asume 898 muestras por ventana y se usan los segmentos 720 a 898)
x1 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df1[898*j+720:898*(j+1)] - df1[898*j:898*j+720].mean()) / df1[898*j:898*j+720].std()
        for j in range(len(df1) // 898)
    ]
])
x2 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df2[898*j+720:898*(j+1)] - df2[898*j:898*j+720].mean()) / df2[898*j:898*j+720].std()
        for j in range(len(df2) // 898)
    ]
])
# Alternar x1 y x2 concatenándolos
xMeanStd = pd.concat([x1, x2], axis=0)

# Ahora, en lugar de asignar directamente (lo que produce error por desajuste de longitudes),
# distribuimos uniformemente los 16 pares en las filas del DataFrame 'df'.
n_blocks = len(xMeanStd)    # Por ejemplo, 16
n_rows = len(df)            # Por ejemplo, 128
k = n_rows // n_blocks      # Número base de repeticiones
remainder = n_rows % n_blocks  # Sobrante

mean_values = []
std_values = []
for i, (mean_val, std_val) in enumerate(xMeanStd):
    reps = k + (1 if i < remainder else 0)
    mean_values.extend([mean_val] * reps)
    std_values.extend([std_val] * reps)

df["mean_values"] = mean_values
df["std_values"] = std_values

# Seleccionar solo las variables relevantes para el modelo (en este ejemplo se usan beta, gamma y std)
#selected_features = ["beta_values", "gamma_values", "std_values"]
selected_features = ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values"]
Y = df["attack_value"].astype(float)  # Variable dependiente
X = df[selected_features].astype(float)  # Variables predictoras

# Agregar una constante
X = sm.add_constant(X)

# Entrenar modelo de regresión logística
model = Logit(Y, X)
results = model.fit()
print(results.summary())

# REPRESENTACIÓN CON SVM
from sklearn import svm
clf = svm.SVC(class_weight="balanced")
clf.fit(X, Y)

# Predicciones y matriz de confusión
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
predictions = clf.predict(X)
cm = confusion_matrix(Y, predictions, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Attack", "Attack"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de confusion usando SVM para ataque en rampa")
#plt.savefig("figuras_memoria/conf_mtx_miercoles_rampa.svg")
#plt.savefig("figuras_memoria/conf_mtx_miercoles_rampa.pdf")
plt.show()

# Métricas
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y, predictions)
precision = precision_score(Y, predictions)
recall = recall_score(Y, predictions)
f1 = f1_score(Y, predictions)
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 score: ", f1)

# Curva ROC
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(Y, predictions)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic, all parameters')
plt.legend(loc="lower right")
plt.show()
# Out:
# Columnas del DataFrame: ['alpha_values', 'beta_values', 'gamma_values', 'delta_values', 'attack_value']
# Optimization terminated successfully.
#          Current function value: 0.595023
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:           attack_value   No. Observations:                12604
# Model:                          Logit   Df Residuals:                    12597
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                  0.1416
# Time:                        16:32:09   Log-Likelihood:                -7499.7
# converged:                       True   LL-Null:                       -8736.4
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
from utilities import *
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit
import matplotlib.pyplot as plt

# Abrir archivos originales (se usan para calcular x1 y x2)
df1 = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_miercoles_diff.csv", header=None)
df2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)

# Ruta del archivo generado por MATLAB
file_path = "matlab_norm/alpha_fit_normalized_miercoles_concatenado_rampa_desl_p1.csv"
df = pd.read_csv(file_path, sep=",")
print("Columnas del DataFrame:", df.columns.tolist())

# Calcular x1 y x2 usando ventanas (se asume 898 muestras por ventana y se usan los segmentos 720 a 898)
x1 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df1[898*j+720:898*(j+1)] - df1[898*j:898*j+720].mean()) / df1[898*j:898*j+720].std()
        for j in range(len(df1) // 898)
    ]
])
x2 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df2[898*j+720:898*(j+1)] - df2[898*j:898*j+720].mean()) / df2[898*j:898*j+720].std()
        for j in range(len(df2) // 898)
    ]
])
# Alternar x1 y x2 concatenándolos
xMeanStd = pd.concat([x1, x2], axis=0)

# Ahora, en lugar de asignar directamente (lo que produce error por desajuste de longitudes),
# distribuimos uniformemente los 16 pares en las filas del DataFrame 'df'.
n_blocks = len(xMeanStd)    # Por ejemplo, 16
n_rows = len(df)            # Por ejemplo, 128
k = n_rows // n_blocks      # Número base de repeticiones
remainder = n_rows % n_blocks  # Sobrante

mean_values = []
std_values = []
for i, (mean_val, std_val) in enumerate(xMeanStd):
    reps = k + (1 if i < remainder else 0)
    mean_values.extend([mean_val] * reps)
    std_values.extend([std_val] * reps)

df["mean_values"] = mean_values
df["std_values"] = std_values

# ----------------------------------------------------
# 1. Construcción o carga del DataFrame 'df'
#    (Incluye aquí tu código de lectura de CSV,
#     cálculos de mean_values/std_values, etc.)
# ----------------------------------------------------
# Supongamos que ya tienes df con las columnas:
# ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values", "attack_value"]

# 2. Definir la variable dependiente (Y) y las predictoras (X)
selected_features = ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values"]
Y = df["attack_value"].astype(float)  # Variable dependiente (0 o 1)
X = df[selected_features].astype(float)

# 3. Agregar la constante para la regresión logística
X = sm.add_constant(X)  # añade columna "const"

# 4. Entrenar el modelo Logit
model = Logit(Y, X)
results = model.fit()
print(results.summary())

# 5. Obtener predicciones de probabilidad y convertirlas a clases (umbral 0.5)
pred_probs = results.predict(X)              # Probabilidades estimadas
pred_classes = (pred_probs >= 0.5).astype(int)  # 0/1

# 6. Matriz de confusión y métricas
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

cm = confusion_matrix(Y, pred_classes, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Attack", "Attack"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

accuracy = accuracy_score(Y, pred_classes)
precision = precision_score(Y, pred_classes)
recall = recall_score(Y, pred_classes)
f1 = f1_score(Y, pred_classes)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)

# 7. Curva ROC
fpr, tpr, _ = roc_curve(Y, pred_classes)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - Logistic Regression')
plt.legend(loc="lower right")
plt.show()
# Out:
# Columnas del DataFrame: ['alpha_values', 'beta_values', 'gamma_values', 'delta_values', 'attack_value']
# Optimization terminated successfully.
#          Current function value: 0.595023
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:           attack_value   No. Observations:                12604
# Model:                          Logit   Df Residuals:                    12597
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                  0.1416
# Time:                        16:32:39   Log-Likelihood:                -7499.7
# converged:                       True   LL-Null:                       -8736.4
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
from utilities import *
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit
import matplotlib.pyplot as plt

# Abrir archivos originales (se usan para calcular x1 y x2)
df1 = pd.read_csv("series_concatenadas_rampa/archivo_concatenado_miercoles_diff.csv", header=None)
#df1 = pd.read_csv("series_concatenadas_rampa/cambio_intensidades/archivo_concatenado_miercoles_intensidad_1+1_5_diff.csv", header=None)
#df1 = pd.read_csv("series_concatenadas_rampa/cambio_intensidades/archivo_concatenado_miercoles_intensidad_1.5_diff.csv", header=None)
df2 = pd.read_csv("series_concatenadas_sin_ataque/archivo_concatenado_miercoles_sin_ataque_diff.csv", header=None)

# Ruta del archivo generado por MATLAB
file_path = "matlab_norm/alpha_fit_normalized_miercoles_concatenado_rampa_desl_p1.csv"
#file_path = "matlab_norm/cambio_intensidades/alpha_fit_normalized_miercoles_concatenado_rampa_desl_p1_intens_1+1_5_2intento.csv"
df = pd.read_csv(file_path, sep=",")
print("Columnas del DataFrame:", df.columns.tolist())

# Calcular x1 y x2 usando ventanas (se asume 898 muestras por ventana y se usan los segmentos 720 a 898)
x1 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df1[898*j+720:898*(j+1)] - df1[898*j:898*j+720].mean()) / df1[898*j:898*j+720].std()
        for j in range(len(df1) // 898)
    ]
])
x2 = pd.Series([
    (float(x_new.mean().iloc[0]), float(x_new.std().iloc[0]))
    for x_new in [
        (df2[898*j+720:898*(j+1)] - df2[898*j:898*j+720].mean()) / df2[898*j:898*j+720].std()
        for j in range(len(df2) // 898)
    ]
])
# Alternar x1 y x2 concatenándolos
xMeanStd = pd.concat([x1, x2], axis=0)

# Ahora, en lugar de asignar directamente (lo que produce error por desajuste de longitudes),
# distribuimos uniformemente los 16 pares en las filas del DataFrame 'df'.
n_blocks = len(xMeanStd)    # Por ejemplo, 16
n_rows = len(df)            # Por ejemplo, 128
k = n_rows // n_blocks      # Número base de repeticiones
remainder = n_rows % n_blocks  # Sobrante

mean_values = []
std_values = []
for i, (mean_val, std_val) in enumerate(xMeanStd):
    reps = k + (1 if i < remainder else 0)
    mean_values.extend([mean_val] * reps)
    std_values.extend([std_val] * reps)

df["mean_values"] = mean_values
df["std_values"] = std_values

from utilities import *
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

# ----------------------------------------------------
# 1. Construcción o carga del DataFrame 'df'
#    (Incluye aquí tu código de lectura de CSV,
#     cálculos de mean_values/std_values, etc.)
# ----------------------------------------------------
# Supongamos que ya tienes df con las columnas:
# ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values", "attack_value"]

# 2. Definir la variable dependiente (Y) y las predictoras (X)
selected_features = ["alpha_values", "beta_values", "gamma_values", "delta_values", "mean_values", "std_values"]
Y = df["attack_value"].astype(float)  # Variable dependiente (0 o 1)
X = df[selected_features].astype(float)

# 3. Entrenar el modelo SVM
clf = svm.SVC(class_weight="balanced")  # "balanced" para dar más peso a la clase minoritaria si la hay
clf.fit(X, Y)

# 4. Obtener predicciones de clase
predictions = clf.predict(X)

# 5. Matriz de confusión y métricas
cm = confusion_matrix(Y, predictions, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Attack", "Attack"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - SVM")
plt.show()

accuracy = accuracy_score(Y, predictions)
precision = precision_score(Y, predictions)
recall = recall_score(Y, predictions)
f1 = f1_score(Y, predictions)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)

# 6. Curva ROC
# Notar que SVC por defecto no produce probabilidades. Puedes usar 'decision_function' para obtener scores.
scores = clf.decision_function(X)

fpr, tpr, _ = roc_curve(Y, scores)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - SVM')
plt.legend(loc="lower right")
plt.show()
# Out:
# Columnas del DataFrame: ['alpha_values', 'beta_values', 'gamma_values', 'delta_values', 'attack_value']
# Accuracy: 0.6793874960330054
# Precision: 0.6876971608832808
# Recall: 0.657251666137734
# F1 score: 0.6721298174442191

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=fpr, y=tpr, mode='lines', name=f'ROC Curve (AUC = {roc_auc:.2f})'))
fig.add_trace(go.Scatter(x=[0, 1], y=[0, 1], mode='lines', name='Random Guess', line=dict(dash='dash')))

fig.update_layout(
    title='ROC Curve',
    xaxis_title='False Positive Rate',
    yaxis_title='True Positive Rate',
    width=700,
    height=500
)
#fig.write_image("figuras_memoria/roc_curve_din_rampa.pdf")

# Guardar en SVG
#fig.write_image("figuras_memoria/roc_curve_din_rampa.svg")

#fig.write_html("figuras_memoria/roc_curve_din_rampa.html")
fig.show()

# %%
#CAMBIO INTENSIDADES 
archivos_miercoles = [
        'series_originales/bitrate_original_mie_0.csv',
        'series_originales/bitrate_original_mie_1.csv',
        'ataque_rampa/cambio_intensidades/bitrate_interval_mie2_intens1+_1_5_2intento.csv', #bitrate_interval_mie2_intens1+0_5_2intento
        'series_originales/bitrate_original_mie_3.csv',
        'series_originales/bitrate_original_mie_4.csv',
        'ataque_rampa/cambio_intensidades/bitrate_interval_mie5_intens1+_1_5_2intento.csv',
        'series_originales/bitrate_original_mie_6.csv',
        'series_originales/bitrate_original_mie_7.csv'
    ]

# Leer cada archivo y guardarlo en una lista de DataFrames
dfs = [pd.read_csv(fp, header=None) for fp in archivos_miercoles]
    
# Concatenar verticalmente (ignorar índices originales)
df_concat = pd.concat(dfs, axis=0, ignore_index=True)
    
# Guardar el resultado en un archivo CSV
#output_file = f"series_concatenadas_rampa/cambio_intensidades/archivo_concatenado_miercoles_intensidad_1+1_5_2intento.csv"
#df_concat.to_csv(output_file, index=False, header=False)
#print(f"Archivo guardado: {output_file}")

# %%
archivo_concatenado_miercoles_intensidad_0_15 = pd.read_csv("series_concatenadas_rampa/cambio_intensidades/archivo_concatenado_miercoles_intensidad_1+1_5_2intento.csv", header=None)
archivo_concatenado_miercoles_intensidad_0_15_diff = archivo_concatenado_miercoles_intensidad_0_15.diff()
#archivo_concatenado_miercoles_intensidad_0_15_diff.dropna().to_csv('series_concatenadas_rampa/cambio_intensidades/archivo_concatenado_miercoles_intensidad_1+1_5_diff.csv', index=False, header=False)
